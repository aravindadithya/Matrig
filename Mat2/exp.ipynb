# %%
import torch
import Mat2.config as c
from utils import trainer as t
from utils import trainer_dfa as t_dfa

# %%
import random
import numpy as np
from utils.layers.linear_rfa import LinearRFA
from utils.layers.linear_dfa import LinearDFA


def networks_have_same_state(net1, net2):
    """Check if two networks have the same initial weight state.
    Handles standard Linear, LinearRFA, and LinearDFA layers.
    """
    net1_layers = [m for m in net1.modules() if isinstance(m, (torch.nn.Linear, LinearRFA, LinearDFA))]
    net2_layers = [m for m in net2.modules() if isinstance(m, (torch.nn.Linear, LinearRFA, LinearDFA))]

    if len(net1_layers) != len(net2_layers):
        print(f"Layer count mismatch: {len(net1_layers)} vs {len(net2_layers)}")
        return False

    for i, (layer1, layer2) in enumerate(zip(net1_layers, net2_layers)):
        if not torch.equal(layer1.weight.data, layer2.weight.data):
            print(f"  Weight mismatch in layer {i}")
            return False

        if layer1.bias is not None and layer2.bias is not None:
            if not torch.equal(layer1.bias.data, layer2.bias.data):
                print(f"  Bias mismatch in layer {i}")
                return False

    return True

# Generate random seeds once, then evaluate every width for each seed.
num_experiments = 1
widths = [784]
random_seeds = [int(random.uniform(100, 100000)) for _ in range(num_experiments)]
print(f"Generated {len(random_seeds)} unique seeds: {random_seeds[:5]}... (showing first 5)")

for exp_num, random_seed in enumerate(random_seeds):
    for width in widths:

        print(f"\n{'='*60}")
        print(f"Experiment {exp_num + 1}/{num_experiments} - Seed: {random_seed} - Width: {width}")
        print(f"{'='*60}")

        config_standard = c.get_config(
            hidden_layers=[width]*3,
            run_id=f"bp_{exp_num}_{random_seed}_width_{width}",
            mode="BP",
            init_method="bp_adversary",
            SEED=random_seed,
        )

        config_rfa = c.get_config(
            hidden_layers=[width]*3,
            run_id=f"rfa_{exp_num}_{random_seed}_width_{width}",
            mode="RFA",
            init_method="bp_adversary",
            SEED=random_seed,
        )

        config_dfa = c.get_config(
            hidden_layers=[width]*3,
            run_id=f"dfa_{exp_num}_{random_seed}_width_{width}",
            mode="DFA",
            init_method="bp_adversary",
            SEED=random_seed,
        )

        '''
        print("Checking if standard, RFA, and DFA start from the same initial state...")
        if not networks_have_same_state(config_standard['net'], config_rfa['net']):
            print("ERROR: Standard and RFA are NOT in the same state!")
            continue
        if not networks_have_same_state(config_standard['net'], config_dfa['net']):
            print("ERROR: Standard and DFA are NOT in the same state!")
            continue
        '''

        print("All three networks start from the SAME initial state!")

        print("\nTraining standard model...")
        t.train_network(config_standard, num_epochs=200, checkpoint_interval=50)

        print("\nTraining RFA model...")
        #t.train_network(config_rfa, num_epochs=200, checkpoint_interval=50)

        print("\nTraining DFA model with the global-output-error path...")
         

        #t_dfa.train_network(config_dfa, num_epochs=200, checkpoint_interval=50)

        print(f"✓ Experiment {exp_num + 1}, width {width} completed successfully!")

print(f"\n{'='*60}")
print(f"All {num_experiments} experiments completed")
print(f"{'='*60}")
# Out:
# Generated 1 unique seeds: [71257]... (showing first 5)
#
# ============================================================
# Experiment 1/1 - Seed: 71257 - Width: 784
# ============================================================
# [Linear(in_features=784, out_features=784, bias=False), Linear(in_features=784, out_features=784, bias=False), Linear(in_features=784, out_features=784, bias=False), Linear(in_features=784, out_features=784, bias=False)]
# Full network W1:N shape: (784, 784)
# sigma_min(T) = 1.00000000
# ||W1:N||_F = 27.99218559
# ||W1:N - T||_F = 0.24999994
# deficiency margin c = 0.75000006
# [LinearRFA(), LinearRFA(), LinearRFA(), LinearRFA()]
# Full network W1:N shape: (784, 784)
# sigma_min(T) = 1.00000000
# ||W1:N||_F = 27.99218559
# ||W1:N - T||_F = 0.24999994
# deficiency margin c = 0.75000006
# Full network W1:N shape: (784, 784)
# sigma_min(T) = 1.00000000
# ||W1:N||_F = 27.99218559
# ||W1:N - T||_F = 0.24999994
# deficiency margin c = 0.75000006
# All three networks start from the SAME initial state!
#
# Training standard model...
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Initializing Wandb:
# wandb: Currently logged in as: g-aravindadithya (ICLR_2027) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/workspaces/Matrig/Mat2/wandb/run-20260831_234341-bp_0_71257_width_784</code>
# Syncing run <strong><a href='https://wandb.ai/ICLR_2027/4_layer_fc_deltaarora/runs/bp_0_71257_width_784' target="_blank">BP_71257_3_784</a></strong> to <a href='https://wandb.ai/ICLR_2027/4_layer_fc_deltaarora' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ICLR_2027/4_layer_fc_deltaarora' target="_blank">https://wandb.ai/ICLR_2027/4_layer_fc_deltaarora</a>
#  View run at <a href='https://wandb.ai/ICLR_2027/4_layer_fc_deltaarora/runs/bp_0_71257_width_784' target="_blank">https://wandb.ai/ICLR_2027/4_layer_fc_deltaarora/runs/bp_0_71257_width_784</a>
# EPOCH:  1
# Time:  0.8339779376983643
# EPOCH:  2
# Time:  0.3992652893066406
# EPOCH:  3
# Time:  0.3865494728088379
# EPOCH:  4
# Time:  0.39902615547180176
# EPOCH:  5
# Time:  0.4702296257019043
# EPOCH:  6
# Time:  0.8723633289337158
# EPOCH:  7
# Time:  0.6159923076629639
# EPOCH:  8
# Time:  0.5715723037719727
# EPOCH:  9
# Time:  0.6046016216278076
# EPOCH:  10
# Time:  0.4359307289123535
# EPOCH:  11
# Time:  0.41284942626953125
# EPOCH:  12
# Time:  0.45789361000061035
# EPOCH:  13
# Time:  0.8166360855102539
# EPOCH:  14
# Time:  0.9664835929870605
# EPOCH:  15
# Time:  0.6992931365966797
# EPOCH:  16
# Time:  0.8169479370117188
# EPOCH:  17
# Time:  0.8452398777008057
# EPOCH:  18
# Time:  0.7270338535308838
# EPOCH:  19
# Time:  0.7802448272705078
# EPOCH:  20
# Time:  0.756864070892334
# EPOCH:  21
# Time:  0.6366629600524902
# EPOCH:  22
# Time:  0.9190783500671387
# EPOCH:  23
# Time:  0.9104619026184082
# EPOCH:  24
# Time:  1.070098638534546
# EPOCH:  25
# Time:  0.8415699005126953
# EPOCH:  26
# Time:  0.7389707565307617
# EPOCH:  27
# Time:  1.1228177547454834
# EPOCH:  28
# Time:  0.8598804473876953
# EPOCH:  29
# Time:  0.7424843311309814
# EPOCH:  30
# Time:  0.7935161590576172
# EPOCH:  31
# Time:  0.879443883895874
# EPOCH:  32
# Time:  0.6437110900878906
# EPOCH:  33
# Time:  0.6340289115905762
# EPOCH:  34
# Time:  0.6465749740600586
# EPOCH:  35
# Time:  0.9891109466552734
# EPOCH:  36
# Time:  0.710334062576294
# EPOCH:  37
# Time:  0.8054673671722412
# EPOCH:  38
# Time:  1.0921282768249512
# EPOCH:  39
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 80
#      77 print("All three networks start from the SAME initial state!")
#      79 print("\nTraining standard model...")
# ---> 80 t.train_network(config_standard, num_epochs=200, checkpoint_interval=50)
#      82 print("\nTraining RFA model...")
#      83 #t.train_network(config_rfa, num_epochs=200, checkpoint_interval=50)
#
# File /workspaces/Matrig/Mat2/../utils/trainer.py:56, in train_network(config, num_epochs, checkpoint_interval)
#      51 logger.log_matrix_diagnostics(i)
#      52 #logger.log_singular_values(i)
#      53 #logger.log_agop(i)
#      54 #logger.count_sparsity(i)
# ---> 56 train_loss_full, train_acc_full , train_preds, train_targets= val_step(net, train_loader, config, lfn)
#      57 val_loss, val_acc, val_preds, val_targets = val_step(net, val_loader, config, lfn)
#      59 train_loss, train_acc = train_step(net, optimizer, lfn, train_loader, config)
#
# File /workspaces/Matrig/Mat2/../utils/trainer.py:188, in val_step(net, val_loader, config, lfn)
#     185 val_loss = None
#     187 memory_format = torch.channels_last if config.get('memory_format') == 'channels_last' else torch.contiguous_format
# --> 188 for batch_idx, batch in enumerate(val_loader):
#     189     inputs, labels = batch
#     190     targets = labels
#
# File /venv/main/lib/python3.12/site-packages/torch/utils/data/dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File /venv/main/lib/python3.12/site-packages/torch/utils/data/dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /venv/main/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50 if self.auto_collation:
#      51     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
#      54         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File /venv/main/lib/python3.12/site-packages/torch/utils/data/dataset.py:413, in Subset.__getitems__(self, indices)
#     411     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     412 else:
# --> 413     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File /venv/main/lib/python3.12/site-packages/torch/utils/data/dataset.py:206, in TensorDataset.__getitem__(self, index)
#     205 def __getitem__(self, index):
# --> 206     return tuple(tensor[index] for tensor in self.tensors)
#
# File /venv/main/lib/python3.12/site-packages/torch/utils/data/dataset.py:206, in <genexpr>(.0)
#     205 def __getitem__(self, index):
# --> 206     return tuple(tensor[index] for tensor in self.tensors)
#
# KeyboardInterrupt:
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7ab3121a2840>> (for post_run_cell), with arguments args (<ExecutionResult object at 7ab3121dbcb0, execution_count=2 error_before_exec=None error_in_exec= info=<ExecutionInfo object at 7ab42447ec30, raw_cell="import random
# import numpy as np
# from utils.layers.." transformed_cell="import random
# import numpy as np
# from utils.layers.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell://dev-container%....ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File /venv/main/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File /venv/main/lib/python3.12/site-packages/wandb/sdk/interface/interface.py:812, in InterfaceBase.publish_resume(self)
#     810 def publish_resume(self) -> None:
#     811     resume = pb.ResumeRequest()
# --> 812     self._publish_resume(resume)
#
# File /venv/main/lib/python3.12/site-packages/wandb/sdk/interface/interface_shared.py:336, in InterfaceShared._publish_resume(self, resume)
#     334 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     335     rec = self._make_request(resume=resume)
# --> 336     self._publish(rec)
#
# File /venv/main/lib/python3.12/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File /venv/main/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:137, in AsyncioManager.run(self, fn)
#     134 future = self._schedule(fn, daemon=False)
#     136 try:
# --> 137     return future.result()
#     139 except concurrent.futures.CancelledError:
#     140     raise RunCancelledError from None
#
# File /venv/main/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /venv/main/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /venv/main/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:220, in AsyncioManager._wrap(self, fn, daemon, name)
#     217     if name and (task := asyncio.current_task()):
#     218         task.set_name(name)
# --> 220     return await fn()
#     221 finally:
#     222     if not daemon:
#
# File /venv/main/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:45, in ServiceClient.publish(self, request)
#      43 async def publish(self, request: spb.ServerRequest) -> None:
#      44     """Send a request without waiting for a response."""
# ---> 45     await self._send_server_request(request)
#
# File /venv/main/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:87, in ServiceClient._send_server_request(self, request)
#      84 self._writer.write(data)
#      86 try:
# ---> 87     await self._drain_writer()
#      88 except Exception as e:
#      89     self._broken_exc = e
#
# File /venv/main/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:96, in ServiceClient._drain_writer(self)
#      94 """Wait for the socket's flow control."""
#      95 if sys.version_info >= (3, 10):
# ---> 96     await self._writer.drain()
#      97     return
#      99 # Prior to 3.10, drain() incorrectly raised an AssertionError when the
#     100 # write buffer was maxed out if called from more than one async task.
#
# File /venv/main/lib/python3.12/asyncio/streams.py:392, in StreamWriter.drain(self)
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
# --> 392 await self._protocol._drain_helper()
#
# File /venv/main/lib/python3.12/asyncio/streams.py:166, in FlowControlMixin._drain_helper(self)
#     164 async def _drain_helper(self):
#     165     if self._connection_lost:
# --> 166         raise ConnectionResetError('Connection lost')
#     167     if not self._paused:
#     168         return
#
# ConnectionResetError: Connection lost

# %%
import math
eta = 0.01
N = 4
c = 3/4

A = max(
        math.sqrt(eta * N),
        2.0 / (eta * (1.0 - c) * (c ** ((N - 1.0) / N))),
        2000.0,
        20.0 / eta,
        (20.0 * ((10.0 ** (2 * N - 1)) / (eta ** (2 * N)))) ** (1.0 / (2 * N - 2)),
    )

#A = (20.0 * ((10.0 ** (2 * N - 1)) / (eta ** (2 * N)))) ** (1.0 / (2 * N - 2))
#A = 2.0 / (eta * (1.0 - c) * (c ** ((N - 1.0) / N)))
#A = math.sqrt(eta * N)
if not math.isfinite(A):
        print("EXPLODDDEEEEEE")
print(f"Calculated A: {A}")
# Out:
# Calculated A: 11224.620483093724

# %%
a = 10**(9)
print(a)
# Out:
# 1000000000

# %%
random_seed= 2982

config_standard = c.get_config(
            hidden_layers=[784]*3,
            run_id=f"bp_{1}_{random_seed}_width_{1024}",
            mode="BP",
            init_method="bp_adversary",
            SEED=random_seed,
        )
# Out:
# [Linear(in_features=784, out_features=784, bias=False), Linear(in_features=784, out_features=784, bias=False), Linear(in_features=784, out_features=784, bias=False), Linear(in_features=784, out_features=784, bias=False)]
# Full network W1:N shape: (784, 784)
# sigma_min(T) = 1.00000000
# ||W1:N||_F = 27.99218559
# ||W1:N - T||_F = 0.24999994
# deficiency margin c = 0.75000006
